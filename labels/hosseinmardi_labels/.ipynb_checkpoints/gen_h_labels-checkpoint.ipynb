# %%
import pandas as pd

# %%
df = pd.read_csv('ledwich_recfluence/channel_review.csv')
df.head()
# Out:
#                      CHANNEL_TITLE                                   TAGS  \
# 0                            Brave                                    NaN
# 1                           GBNews  AntiSJW|Mainstream News|PartisanRight
# 2  The Black Conservative Preacher            AntiSJW|PartisanRight|QAnon
# 3    Energy and Commerce Committee                            StateFunded
# 4              That Star Wars Girl                                AntiSJW
#
#                  CHANNEL_ID LR  RELEVANCE REVIEWER_LR  \
# 0  UCFNTTISby1c_H-rm5Ww5rZg  C        0.0           C
# 1  UC0vn8ISa4LKMunLbzaXLnOQ  R        1.0           R
# 2  UC_QYq3wFd46rcaoKOvPHFgA  R        1.0           R
# 3  UCCbD3bkHRcwiBsaL1lWE_QQ  C        1.0           C
# 4  UCRWsFMLzGGJKLnAXJ9U93_A  R        0.8           R
#
#                            REVIEWER_TAGS REVIEWER_MAIN_CHANNEL_ID  \
# 0                                    NaN                      NaN
# 1  AntiSJW|Mainstream News|PartisanRight                      NaN
# 2            PartisanRight|QAnon|AntiSJW                      NaN
# 3                            StateFunded                      NaN
# 4                                AntiSJW                      NaN
#
#    REVIEWER_RELEVANCE REVIEWER_CODE                       UPDATED  \
# 0                 0.0           mar  2021-12-22T01:00:52.5691836Z
# 1                 1.0           mar  2021-10-25T21:17:49.7200458Z
# 2                 1.0           mar  2021-06-08T01:27:45.4527338Z
# 3                 1.0           mar  2021-03-26T02:15:09.3585105Z
# 4                 0.8           mar  2021-03-16T01:24:18.9299734Z
#
#                                PUBLIC_REVIEWER_NOTES PUBLIC_CREATOR_NOTES
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2  This is the channel that had the senator who l...                  NaN
# 3                                                NaN                  NaN
# 4                                                NaN                  NaN

# %%
# Taking an extreme approach here, i.e. map to most extreme category first
ledwich_map = [
    ('FL', {'Socialist'}),
    ('FR', {'WhiteIdentitarian', 'QAnon', 'Conspiracy'}),
    ('AW', {'AntiSJW', 'MRA'}),
    ('L', {'MainstreamNews(L)', 'Left', 'PartisanLeft',
           'SocialJustice'}),
    ('R', {'MainstreamNews(R)', 'Right', 'PartisanRight',
           'ReligiousConservative', 'Libertarian(R)'}),
    ('C', {'MainstreamNews(C)', 'Center'})
]

# %%
def map_labels(tag_line, label_map):
    if pd.isna(tag_line):
        return None
    tags = set(tag_line.split("|"))
    for mapping in label_map:
        new_label, old_labels = mapping
        if len(old_labels.intersection(tags))>0:
            return new_label
    return None

# %%
new_labels = df.apply(
    lambda row: map_labels(row['TAGS'], ledwich_map), 
    axis=1
)

# %%
df['H_TAG'] = new_labels

# %%
df.head()
# Out:
#                      CHANNEL_TITLE                                   TAGS  \
# 0                            Brave                                    NaN
# 1                           GBNews  AntiSJW|Mainstream News|PartisanRight
# 2  The Black Conservative Preacher            AntiSJW|PartisanRight|QAnon
# 3    Energy and Commerce Committee                            StateFunded
# 4              That Star Wars Girl                                AntiSJW
#
#                  CHANNEL_ID LR  RELEVANCE REVIEWER_LR  \
# 0  UCFNTTISby1c_H-rm5Ww5rZg  C        0.0           C
# 1  UC0vn8ISa4LKMunLbzaXLnOQ  R        1.0           R
# 2  UC_QYq3wFd46rcaoKOvPHFgA  R        1.0           R
# 3  UCCbD3bkHRcwiBsaL1lWE_QQ  C        1.0           C
# 4  UCRWsFMLzGGJKLnAXJ9U93_A  R        0.8           R
#
#                            REVIEWER_TAGS REVIEWER_MAIN_CHANNEL_ID  \
# 0                                    NaN                      NaN
# 1  AntiSJW|Mainstream News|PartisanRight                      NaN
# 2            PartisanRight|QAnon|AntiSJW                      NaN
# 3                            StateFunded                      NaN
# 4                                AntiSJW                      NaN
#
#    REVIEWER_RELEVANCE REVIEWER_CODE                       UPDATED  \
# 0                 0.0           mar  2021-12-22T01:00:52.5691836Z
# 1                 1.0           mar  2021-10-25T21:17:49.7200458Z
# 2                 1.0           mar  2021-06-08T01:27:45.4527338Z
# 3                 1.0           mar  2021-03-26T02:15:09.3585105Z
# 4                 0.8           mar  2021-03-16T01:24:18.9299734Z
#
#                                PUBLIC_REVIEWER_NOTES PUBLIC_CREATOR_NOTES  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2  This is the channel that had the senator who l...                  NaN
# 3                                                NaN                  NaN
# 4                                                NaN                  NaN
#
#   H_TAG
# 0  None
# 1    AW
# 2    FR
# 3  None
# 4    AW

# %%
f = 'ribeiro_radicalization_pathways/'
ribeiro_map = {
    'L': ['mainstream/left.csv', 'mainstream/left-center.csv'],
    'C': ['mainstream/center.csv'],
    'AW': ['idw.csv'],
    'R': ['mainstream/right-center.csv', 'mainstream/right.csv', 'alt-lite.csv'],
    'FR': ['alt-right.csv']
}

# %%
df_ribeiro = pd.DataFrame(index=['CHANNEL_TITLE', 'H_TAG'])
for category, lists in ribeiro_map.items():
    for file in lists:
        df_channel_list = pd.read_csv(f+file, names=['CHANNEL_TITLE'])
        df_ribeiro = pd.concat([df_ribeiro, df_channel_list])

# %%
df_ribeiro
# Out:
#                                 CHANNEL_TITLE
# CHANNEL_TITLE                             NaN
# H_TAG                                     NaN
# 0                                cosmopolitan
# 1                               democracy now
# 2                                 elite daily
# ...                                       ...
# 83                                  TRS Radio
# 84                              The Leftovers
# 85                                   The Lion
# 86             The Revolutionary Conservative
# 87                             VertigoPolitix
#
# [362 rows x 1 columns]
